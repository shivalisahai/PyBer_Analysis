# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
cities = ["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"]
bars_in_cities = [8.6, 8.5, 8.3, 7.9, 7.2]
x_axis = np.arange(len(bars_in_cities))

# %%
# Create a bar chart based upon the above data
plt.bar(cities,bars_in_cities)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 5 artists>

# %%
# Create the ticks for our bar chart's x axis
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations,["8.6","8.5","8.3","7.9","7.2"] )
# Out:
# ([<matplotlib.axis.XTick at 0x23ce63e91f0>,
#   <matplotlib.axis.XTick at 0x23ce63e91c0>,
#   <matplotlib.axis.XTick at 0x23ce6422730>,
#   <matplotlib.axis.XTick at 0x23ce6422ca0>,
#   <matplotlib.axis.XTick at 0x23ce642b310>],
#  [Text(0, 0, '8.6'),
#   Text(1, 0, '8.5'),
#   Text(2, 0, '8.3'),
#   Text(3, 0, '7.9'),
#   Text(4, 0, '7.2')])

# %%
# Set the limits of the x axis
plt.xlim(-0.75, len(x_axis)-0.25)
# Out:
# (-0.75, 4.75)

# %%
# Set the limits of the y axis
plt.ylim(0,max(cities)+10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13108/368002924.py in <module>
#       1 # Set the limits of the y axis
# ----> 2 plt.ylim(0,max(cities)+1)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Give the chart a title, x label, and y label

# %%
# Save an image of the chart and print it to the screen
