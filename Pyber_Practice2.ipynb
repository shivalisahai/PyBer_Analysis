# %%
import matplotlib.pyplot as plt

# %%
savings = [0,100, 150, 200, 300, 500, 300, 350, 500,600, 750, 1000]
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

# %%
plt.plot(months, savings)
plt.xlabel("Month")
plt.ylabel("Savings ($)")
plt.title("Saving Account Results")
plt.show()

# %%
plt.pie(y_axis, labels=x_axis)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28996\2095593267.py in <module>
# ----> 1 plt.pie(y_axis, labels=x_axis)
#       2 plt.show()
#
# NameError: name 'y_axis' is not defined
